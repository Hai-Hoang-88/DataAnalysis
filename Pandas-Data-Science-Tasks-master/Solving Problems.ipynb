# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

pd.options.mode.chained_assignment = None

# %% [markdown]
# ### Mergin 12 months of sales data into a single CSV file

# %%
url = "./SalesAnalysis/Sales_Data/"
df = pd.read_csv(url + "Sales_April_2019.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
all_months_data = pd.DataFrame()
for file in os.listdir(url):
    df = pd.read_csv(url + file)
    all_months_data = pd.concat([all_months_data, pd.read_csv(url+file)])
    print(df.shape)
all_months_data.shape
# Out:
# (18383, 6)
# (12011, 6)
# (25117, 6)
# (12036, 6)
# (9723, 6)
# (14371, 6)
# (13622, 6)
# (15226, 6)
# (16635, 6)
# (17661, 6)
# (20379, 6)
# (11686, 6)
# (186850, 6)

# %%
all_months_data.isna()
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0         False    False             False       False       False
# 1          True     True              True        True        True
# 2         False    False             False       False       False
# 3         False    False             False       False       False
# 4         False    False             False       False       False
# ...         ...      ...               ...         ...         ...
# 11681     False    False             False       False       False
# 11682     False    False             False       False       False
# 11683     False    False             False       False       False
# 11684     False    False             False       False       False
# 11685     False    False             False       False       False
#
#        Purchase Address
# 0                 False
# 1                  True
# 2                 False
# 3                 False
# 4                 False
# ...

# %%
all_months_data = all_months_data.dropna(how="all")

# %%
all_months_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
all_months_data.to_csv("All_Data.csv",index = False)

# %% [markdown]
# #### Read in updated dataframe

# %%
all_data = pd.read_csv("All_Data.csv")

# %% [markdown]
# #### Cleanup the data!

# %%
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186300   259353      AAA Batteries (4-pack)                3       2.99
# 186301   259354                      iPhone                1        700
# 186302   259355                      iPhone                1        700
# 186303   259356      34in Ultrawide Monitor                1     379.99
# 186304   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Augment data with additional columns

# %% [markdown]
# #### Add Month Column

# %%
all_data["Month"] = all_data["Order Date"].str[:2]

# %% [markdown]
# #### because we merge multiple csv file with header so there are few header rows in the files
# So we need to remove those rows

# %%
all_data.iloc[517]
# Out:
# Order ID                    Order ID
# Product                      Product
# Quantity Ordered    Quantity Ordered
# Price Each                Price Each
# Order Date                Order Date
# Purchase Address    Purchase Address
# Month                             Or
# Name: 517, dtype: object

# %%
all_data = all_data[all_data["Month"].str[0:2] != "Or"]

# %%
all_data["Month"] = pd.to_numeric(all_data["Month"])

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186304
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 11.3+ MB

# %% [markdown]
# ### Add a city column

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
def get_city(address):
    return address.split(",")[1]

def get_state(address):
    return address.split(",")[2].split(" ")[1]


all_data["City"] = all_data["Purchase Address"].apply(lambda x : f"{get_city(x)} ({get_state(x)})")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#                 City
# 0        Dallas (TX)
# 1        Boston (MA)
# 2   Los Angeles (CA)
# 3   Los Angeles (CA)
# 4   Los Angeles (CA)

# %% [markdown]
# #### Add a sales column

# %%
all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"])
all_data["Price Each"] = pd.to_numeric(all_data["Price Each"])

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186304
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int64
#  7   City              185950 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 12.8+ MB

# %%
all_data["Sale"] = all_data["Quantity Ordered"] * all_data["Price Each"]

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186300   259353      AAA Batteries (4-pack)                 3        2.99
# 186301   259354                      iPhone                 1      700.00
# 186302   259355                      iPhone                 1      700.00
# 186303   259356      34in Ultrawide Monitor                 1      379.99
# 186304   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %% [markdown]
# #### Question 1: what is the month sale and how much is it

# %%
SaleByMonth = all_data.groupby("Month").sum()

# %%
SaleByMonth["Sale"]
# Out:
# Month
# 1     1.822257e+06
# 2     2.202022e+06
# 3     2.807100e+06
# 4     3.390670e+06
# 5     3.152607e+06
# 6     2.577802e+06
# 7     2.647776e+06
# 8     2.244468e+06
# 9     2.097560e+06
# 10    3.736727e+06
# 11    3.199603e+06
# 12    4.613443e+06
# Name: Sale, dtype: float64

# %%
MaxSale = SaleByMonth["Sale"].max()
MonthOfMaxSale = SaleByMonth[SaleByMonth["Sale"] == MaxSale]
MonthOfMaxSale
# Out:
#        Quantity Ordered    Price Each          Sale
# Month
# 12                28114  4.588415e+06  4.613443e+06

# %%
MinSale = SaleByMonth["Sale"].min()
MonthOfMinSale = SaleByMonth[SaleByMonth["Sale"] == MinSale]
MonthOfMinSale
# Out:
#        Quantity Ordered  Price Each        Sale
# Month
# 1                 10903  1811768.38  1822256.73

# %%
month = np.arange(1,13) # also there is another way to get the data

# %%
plt.bar(month, SaleByMonth["Sale"])
plt.xticks(month)
plt.xlabel("Months")
plt.ylabel("Sales in USD")
plt.show()

# %% [markdown]
# ### Question 2: What city had the highest sale

# %%
SaleByCity = all_data.groupby("City").sum()
SaleByCity
# Out:
#                      Quantity Ordered    Price Each   Month          Sale  \
# City
#  Atlanta (GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin (TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston (MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas (TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles (CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City (NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland (ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland (OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco (CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle (WA)                   16553  2.733296e+06  104941  2.747755e+06
#
#                        Hour     Mins
# City
#  Atlanta (GA)        214264   442932
#  Austin (TX)         141946   289060
# ...

# %%
cities = [city for city, df in all_data.groupby("City")]

plt.bar(cities, SaleByCity["Sale"])
plt.title("Sale by Citites", size=17)
plt.xticks(cities, rotation="vertical", size=8)
plt.xlabel("Cities")
plt.ylabel("Sale in USD")
plt.show()

## noted with rotation for ticks

# %% [markdown]
# ### Q3: What is the best time for advertisement in place to maximize likelihood of customers's buying products?
# - we have Order Data but not in correct format --> convert to datetime format
# - Create columns with Hours and Mins
# - Plot line graph with Hours ticks with `hours = [hours for hours, df in DataFrame.groupby("Hours")]`

# %%
all_data["Order Date"] = pd.to_datetime(all_data["Order Date"])
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City    Sale  Hour  Mins
# 0        Dallas (TX)   23.90     8    46
# 1        Boston (MA)   99.99    22    30
# ...

# %%
all_data["Hour"] = all_data["Order Date"].dt.hour
all_data["Mins"] = all_data["Order Date"].dt.minute
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City    Sale  Hour  Mins
# 0        Dallas (TX)   23.90     8    46
# 1        Boston (MA)   99.99    22    30
# ...

# %%
hours = [hours for hours, df in all_data.groupby("Hour")]

plt.plot(hours, all_data.groupby("Hour").count())
plt.grid()
plt.xlabel("Hours")
plt.ylabel("Order Number")
plt.show()

# noted how we use count() instead of sum()

# %% [markdown]
# ### Q4: What product are most often sold together?
# Thought:
# - Items sold together when there are same Order ID in the Data
# Steps:
# - We filter Order ID if it is duplicate by using `DataFrame.duplicated()`

# %%
df = all_data[all_data["Order ID"].duplicated(keep=False)]
df["GroupedItems"] = df.groupby("Order ID")["Product"].transform(lambda x: ", ".join(x))

df = df[["Order ID", "GroupedItems"]].drop_duplicates()
df.head()
# Out:
#     Order ID                                       GroupedItems
# 2     176560                     Google Phone, Wired Headphones
# 17    176574                 Google Phone, USB-C Charging Cable
# 29    176585  Bose SoundSport Headphones, Bose SoundSport He...
# 31    176586               AAA Batteries (4-pack), Google Phone
# 118   176672     Lightning Charging Cable, USB-C Charging Cable

# %%
from itertools import combinations
from collections import Counter

count =  Counter()

for row in df["GroupedItems"]:
    row_list = row.split(", ")
    count.update(Counter(combinations(row_list, 2)))
    
for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### Q4: What products we sold the most? Why do you think it was?
# **Thought**:
# - sumup of Quantity Ordered Groupby the Product
#
# **Actions**:
# - Sumup
# - Plot
# - Compare the Pirce with number of Order checking the correlation

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City    Sale  Hour  Mins
# 0        Dallas (TX)   23.90     8    46
# 1        Boston (MA)   99.99    22    30
# ...

# %%
all_data.groupby("Product").sum()
# Out:
#                             Quantity Ordered  Price Each   Month        Sale  \
# Product
# 20in Monitor                            4129   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# 27in FHD Monitor                        7550  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                  27635    79015.68  145558   106118.40
# AAA Batteries (4-pack)                 31017    61716.59  146370    92740.83
# Apple Airpods Headphones               15661  2332350.00  109477  2349150.00
# Bose SoundSport Headphones             13457  1332366.75   94113  1345565.43
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# LG Dryer                                 646   387600.00    4383   387600.00
# ...

# %%
product = [product for product, df in all_data.groupby("Product")]

plt.scatter()

plt.scatter(product, all_data.groupby("Product")["Quantity Ordered"].sum())
plt.grid()
plt.xticks(product, rotation=90, size=8)
plt.xlabel("Products")
plt.ylabel("Number of Order")
plt.show();

# %%
prices = all_data.groupby("Product").mean()["Price Each"]

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(product, all_data.groupby("Product")["Quantity Ordered"].sum())
ax2.plot(product, prices, "r--", marker="o")

ax1.set_xlabel("Product")
ax1.set_ylabel("Number of Ordered", color="b")
ax1.set_xticklabels(product, rotation="vertical")
ax2.set_ylabel("Price Each", color="r")

plt.show();
# Out:
# <ipython-input-99-ae2dc86e160d>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(product, rotation="vertical")
